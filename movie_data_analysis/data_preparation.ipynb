# %%
import pandas as pd
import numpy as np
import csv

df = pd.read_csv("movies_metadata.csv", dtype={'popularity': 'str'})

# %%
# remove entries where release date is na
df = df.dropna(subset=["release_date", "title"])

# drop useless columns (tagline ? belongs_to_collection ? runtime ?
df = df.drop(columns=["adult", "poster_path", "homepage", "video", "original_title", "belongs_to_collection"])

df["release_year"] = df["release_date"].str[:4]

# vote count 0 ?
# budget == 0 pour 36000 rows 
df
# Out:
#          budget                                             genres      id  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2             0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4             0                     [{'id': 35, 'name': 'Comedy'}]   11862
# ...         ...                                                ...     ...
# 45457         0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45459         0                      [{'id': 18, 'name': 'Drama'}]  111109
# 45460         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45461         0                                                 []  227506
# 45462         0                                                 []  461257
#
#          imdb_id original_language  \
# 0      tt0114709                en
# 1      tt0113497                en
# 2      tt0113228                en
# 3      tt0114885                en
# 4      tt0113041                en
# ...          ...               ...
# 45457  tt0102797                en
# 45459  tt2028550                tl
# 45460  tt0303758                en
# 45461  tt0008536                en
# 45462  tt6980792                en
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45457  Yet another version of the classic epic, with ...   5.683753
# 45459  An artist struggles to finish his work while a...   0.178241
# 45460  When one of her hits goes wrong, a professiona...   0.903007
# 45461  In a small town live two brothers, one a minis...   0.003503
# 45462  50 years after decriminalisation of homosexual...   0.163015
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45457  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45459             [{'name': 'Sine Olivia', 'id': 19653}]
# 45460  [{'name': 'American World Pictures', 'id': 6165}]
# 45461               [{'name': 'Yermoliev', 'id': 88753}]
# 45462                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45457  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13
# 45459      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45460  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45461           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45462   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#          revenue  runtime                                   spoken_languages  \
# 0      373554033     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...          ...      ...                                                ...
# 45457          0    104.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45459          0    360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45460          0     90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45461          0     87.0                                                 []
# 45462          0     75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45457  Released                                                NaN
# 45459  Released                                                NaN
# 45460  Released                             A deadly game of wits.
# 45461  Released                                                NaN
# 45462  Released                                                NaN
#
#                              title  vote_average  vote_count release_year
# 0                        Toy Story           7.7        5415         1995
# 1                          Jumanji           6.9        2413         1995
# 2                 Grumpier Old Men           6.5          92         1995
# 3                Waiting to Exhale           6.1          34         1995
# 4      Father of the Bride Part II           5.7         173         1995
# ...                            ...           ...         ...          ...
# 45457                   Robin Hood           5.7          26         1991
# 45459          Century of Birthing           9.0           3         2011
# 45460                     Betrayal           3.8           6         2003
# 45461             Satan Triumphant           0.0           0         1917
# 45462                     Queerama           0.0           0         2017
#
# [45379 rows x 19 columns]

# %% [markdown]
# Est ce qu'on enlève la row quand le vote count est 0
#
# Budget == 0 pour 36000 rows => pas de données.
# Est ce que 9000 seront assez pour l'analyse (voir répartition) ?

# %% [markdown]
# ### Production de films

# %%
section1 = df.drop(columns=["imdb_id", "runtime", "revenue", "vote_count", "vote_average", "status", "popularity", "tagline", "overview", "production_companies", "production_countries", "title", "spoken_languages", "release_date", "id", "original_language"])
section1.to_csv("evolution_production/data/production.csv")

# %% [markdown]
# ### Critique vs Budget

# %%
section2 = df.drop(columns=["id", "overview", "production_companies", "tagline", "spoken_languages", "production_countries", "imdb_id"])
section2 = section2.drop(section2[section2["budget"] == "0"].index)
section2.to_csv("critique_budget/data/critique_budget.csv")

# %% [markdown]
# ### Popularité et thème

# %%
section3 = df.drop(columns=["id", "imdb_id", "production_countries", "production_companies"])
section3 = section3.drop(section3[section3["budget"] == "0"].index)
section3 = section3.drop(section3[section3["revenue"] == 0].index)
section3.to_csv("theme_popularite/data/theme_popularite.csv")

# %% [markdown]
# ### Production et monopole

# %%
section4 = df.drop(columns=["genres", "id", "imdb_id", "overview", "tagline"])
section4 = section4.drop(section4[section4["budget"] == "0"].index)

companies = section4.copy()
companies = companies.drop(companies[companies["production_companies"] == "[]"].index)
companies = companies.drop(columns=["production_countries"])

countries = section4.copy()
countries = countries.drop(countries[countries["production_countries"] == "[]"].index)
countries = countries.drop(columns=["production_companies"])

companies.to_csv("producteurs/data/entreprises_producteurs.csv")
countries.to_csv("producteurs/data/pays_producteurs.csv")

# %% [markdown]
# ### Keywords et popularité

# %%
section5 = df.drop(columns=["budget", "id", "imdb_id", "production_companies", "production_countries", "spoken_languages"])
section5.to_csv("keywords_popularite/data/keywords_popularite.csv")

# %% [markdown]
# ### Expérimentation

# %%
# df[df["status"] == "Rumored"]

# na = df.isna()
# na[na["release_date"] == True]

# empty_prd_country = df[df["production_countries"] == "[]"]
# empty_prd_company = df[df["production_companies"] == "[]"]

# empty_prd_company

df[df["original_language"].isna()]
# df[df["budget"] == "0"]
# Out:
#        budget                                             genres      id  \
# 19574       0                [{'id': 99, 'name': 'Documentary'}]  283101
# 21601       0  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...  103902
# 22831       0  [{'id': 10752, 'name': 'War'}, {'id': 37, 'nam...  359195
# 32139       0                     [{'id': 35, 'name': 'Comedy'}]  147050
# 37404       0                  [{'id': 16, 'name': 'Animation'}]  257095
# 41044       0                [{'id': 99, 'name': 'Documentary'}]  332742
# 41869       0                [{'id': 99, 'name': 'Documentary'}]  144410
# 44054       0                      [{'id': 18, 'name': 'Drama'}]  380438
# 44407       0  [{'id': 16, 'name': 'Animation'}, {'id': 99, '...  381096
# 44573       0                                                 []  381525
# 44652       0  [{'id': 28, 'name': 'Action'}, {'id': 10752, '...  104473
#
#          imdb_id original_language  \
# 19574  tt0429086               NaN
# 21601  tt0838231               NaN
# 22831  tt0053558               NaN
# 32139  tt0122580               NaN
# 37404  tt0225145               NaN
# 41044  tt4432912               NaN
# 41869  tt0154152               NaN
# 44054  tt0298411               NaN
# 44407  tt5333518               NaN
# 44573  tt5376720               NaN
# 44652  tt0223958               NaN
#
#                                                 overview popularity  \
# 19574  Documentary about the production of The Third ...   0.017007
# 21601  An Outback farmer takes in an Afghani woman wh...   0.359818
# 22831  A group of Union Army soldiers is charged with...   0.070647
# 32139  George and Gracie enter an elegant drawing roo...   0.073418
# 37404  The first fairy tale transformed into a full-l...   0.036841
# 41044  Until the late 1970s, the Pakistani city of La...   0.373688
# 41869  Two dancers perform in succession facing a sta...    1.58434
# 44054                                                NaN   0.001283
# 44407  The traditional crafts of crochet and knitting...   0.067624
# 44573  American investment fund buys Austrian compani...   0.030766
# 44652  Three military men, seen inside a fortificatio...   0.471325
#
#                                     production_companies  \
# 19574  [{'name': 'StudioCanal', 'id': 694}, {'name': ...
# 21601  [{'name': 'New Holland Pictures', 'id': 10229}...
# 22831  [{'name': 'Associated Producers (API)', 'id': ...
# 32139  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 37404  [{'name': 'Ceskoslovenský Státní Film', 'id': ...
# 41044                                                 []
# 41869  [{'name': 'Edison Manufacturing Company', 'id'...
# 44054                                                 []
# 44407                                                 []
# 44573                                                 []
# 44652                [{'name': 'Star-Film', 'id': 7159}]
#
#                                     production_countries release_date  \
# 19574  [{'iso_3166_1': 'AT', 'name': 'Austria'}, {'is...   2004-10-11
# 21601        [{'iso_3166_1': 'AU', 'name': 'Australia'}]   2007-08-04
# 22831  [{'iso_3166_1': 'US', 'name': 'United States o...   1960-03-31
# 32139  [{'iso_3166_1': 'US', 'name': 'United States o...   1929-10-31
# 37404   [{'iso_3166_1': 'CZ', 'name': 'Czech Republic'}]   1950-01-26
# 41044                                                 []   2015-11-13
# 41869  [{'iso_3166_1': 'US', 'name': 'United States o...   1895-04-01
# 44054           [{'iso_3166_1': 'FR', 'name': 'France'}]   2001-01-01
# 44407                                                 []   2016-03-12
# 44573          [{'iso_3166_1': 'AT', 'name': 'Austria'}]   2016-01-27
# 44652           [{'iso_3166_1': 'FR', 'name': 'France'}]   1897-01-01
#
#        revenue  runtime                                   spoken_languages  \
# 19574        0     95.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 21601        0     94.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 22831        0     69.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 32139        0      8.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 37404        0     87.0             [{'iso_639_1': 'cs', 'name': 'Český'}]
# 41044        0     82.0  [{'iso_639_1': 'ur', 'name': 'اردو'}, {'iso_63...
# 41869        0      1.0       [{'iso_639_1': 'xx', 'name': 'No Language'}]
# 44054        0      0.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 44407        0     76.0  [{'iso_639_1': 'sv', 'name': 'svenska'}, {'iso...
# 44573        0     84.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 44652        0      1.0       [{'iso_639_1': 'xx', 'name': 'No Language'}]
#
#          status tagline                       title  vote_average  vote_count  \
# 19574  Released     NaN     Shadowing the Third Man           0.0           0
# 21601  Released     NaN              Unfinished Sky           6.4           8
# 22831  Released     NaN             13 Fighting Men           0.0           0
# 32139  Released     NaN                   Lambchops           6.5           2
# 37404  Released     NaN               Prince Bayaya           5.0           1
# 41044  Released     NaN              Song of Lahore           6.5           2
# 41869  Released     NaN  Annabelle Serpentine Dance           5.7          20
# 44054  Released     NaN       Lettre d'une inconnue           0.0           0
# 44407  Released     NaN                        Yarn           0.0           0
# 44573  Released     NaN                      WiNWiN           0.0           0
# 44652   Rumored     NaN  The Surrender of Tournavos           4.6           5
#
#       release_year
# 19574         2004
# 21601         2007
# 22831         1960
# 32139         1929
# 37404         1950
# 41044         2015
# 41869         1895
# 44054         2001
# 44407         2016
# 44573         2016
# 44652         1897
