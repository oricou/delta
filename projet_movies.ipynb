# %%
from tmdbv3api import TMDb, Discover

tmdb = TMDb()
tmdb.api_key = 'fd5bdbb2e9284468c4f6a4f3dc74a1e4'

discover = Discover()
movies = []
for date in range(1950, 2023):
    for page in range(1,6):
        movies += discover.discover_movies({"primary_release_year":date, "page":page})

len(movies)
# Out:
# 7300

# %%
# import requests
# import json

# r = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=fd5bdbb2e9284468c4f6a4f3dc74a1e4&language=en-US&include_video=false')
# len(r.json()["results"])

# %%
import csv
import pandas as pd

with open('movies.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, ["adult", "backdrop_path", "genre_ids", "id", "original_language", "original_title", "overview", "popularity", "poster_path", "release_date", "title", "video", "vote_average", "vote_count"])
    writer.writeheader()
    writer.writerows(movies)



df = pd.read_csv("movies.csv")

df.drop(columns=["backdrop_path", "poster_path", "adult", "video"])
# Out:
#                    genre_ids      id original_language  \
# 0     [10751, 14, 16, 10749]   11224                en
# 1                       [18]     599                en
# 2                       [18]     705                en
# 3         [18, 53, 80, 9648]   19119                en
# 4             [80, 18, 9648]     548                ja
# ...                      ...     ...               ...
# 7295             [35, 10749]  832277                it
# 7296                      []  901908                es
# 7297                    [99]  913862                en
# 7298               [878, 35]  665828                fr
# 7299             [35, 10749]  892835                en
#
#                          original_title  \
# 0                            Cinderella
# 1                      Sunset Boulevard
# 2                         All About Eve
# 3                    Night and the City
# 4                                   羅生門
# ...                                 ...
# ...
